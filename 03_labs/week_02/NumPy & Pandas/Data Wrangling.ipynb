# %% [markdown]
# ## Advanced Data Wrangling with Pandas and Numpy

# %% [markdown]
# ## Table of Contents
# * Importing the Dataset
# * Merge and join the transaction data and weekly product data
# * Handle missing values
# * Reshape the dataset

# %%
## Importing the necessary libraries
import pandas as pd
import numpy as np

# %%
transactions = pd.read_csv("C:\Users\UthmanAbdulrahman\Documents\Week 2 Day 2\Day 2\nigerian_market_transactions_1000.csv")
# Out:
#   Cell In[5], line 1
#     transactions = pd.read_csv("C:\Users\UthmanAbdulrahman\Documents\Week 2 Day 2\Day 2\nigerian_market_transactions_1000.csv")
#                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
