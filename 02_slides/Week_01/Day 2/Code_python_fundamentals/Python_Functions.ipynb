# %% [markdown]
# ## Part 1: Function Basics - From Simple to Complex
#
# ### Example 1.1: Building Your First Function
#
# **Teaching Goal:** Show the transition from repeated code to a reusable function
